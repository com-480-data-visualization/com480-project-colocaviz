# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_production_livestock = pd.read_csv("data/Production_Crops_Livestock_E_All_Data.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14096\285580981.py:1: DtypeWarning: Columns (11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92,95,98,101,104,107,110,113,116,119,122,125,128,131,134,137,140,143,146,149,152,155,158,161,164,167,170,173,176,179,182,185,188,191,194,197) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_production_livestock = pd.read_csv("data/Production_Crops_Livestock_E_All_Data.csv")

# %%
df_production_livestock = df_production_livestock[df_production_livestock["Element"]=="Production"]
df_production_livestock.describe()
# Out:
#           Area Code     Item Code  Element Code         Y1961         Y1962  \
# count  31107.000000  31107.000000  31107.000000  2.309200e+04  2.308700e+04
# mean    1317.629247    845.688720   5510.030861  1.288094e+06  1.313496e+06
# std     2197.493167   1367.396309      0.302711  1.277778e+07  1.293848e+07
# min        1.000000     15.000000   5510.000000  0.000000e+00  0.000000e+00
# 25%       89.000000    331.000000   5510.000000  8.028900e+02  8.568200e+02
# 50%      170.000000    603.000000   5510.000000  1.031340e+04  1.076000e+04
# 75%      272.000000   1035.000000   5510.000000  1.080878e+05  1.112194e+05
# max     5817.000000  17530.000000   5513.000000  8.768745e+08  9.333729e+08
#
#               Y1963         Y1964         Y1965         Y1966         Y1967  \
# count  2.308700e+04  2.308700e+04  2.308800e+04  2.309100e+04  2.308900e+04
# mean   1.339129e+06  1.414666e+06  1.449638e+06  1.505192e+06  1.558679e+06
# ...

# %%
def year_string_to_int(year_string):
    return

# %%
df_production_livestock

# %%
df_production_livestock.pivot(index=["Y"+str(year) for year in range(1961,2024)], columns='', values='baz')bar

# %%
df_production_livestock.columns
# Out:
# Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item Code (CPC)',
#        'Item', 'Element Code', 'Element', 'Unit', 'Y1961',
#        ...
#        'Y2020N', 'Y2021', 'Y2021F', 'Y2021N', 'Y2022', 'Y2022F', 'Y2022N',
#        'Y2023', 'Y2023F', 'Y2023N'],
#       dtype='object', length=198)

# %%
for year in range(1961,2024):
    column_name= "Y" +str(year)
    df_production_livestock.rename{}
